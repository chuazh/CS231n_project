# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.loadtxt('vis_gt.dat',delimiter = ',')
scores = np.loadtxt('vis_scores.dat', delimiter = ',')

plt.figure()
for i in range(14):
    plt.subplot(14,1,i+1)
    plt.plot(scores[:,i],'r')
    plt.plot(y[:,i],'b')


import pickle

f = open('train_loss.dat','rb')
train_loss = pickle.load(f)
f.close()
f = open('val_loss.dat','rb')
val_loss = pickle.load(f)
f.close()

print(train_loss)

plt.figure()
plt.plot(train_loss)
plt.plot(val_loss)
# Out:
# [16.78508071899414, 13.056091451644898, 10.746422131856283, 9.227654230594634, 3.833063268661499, 3.4895419597625734, 3.2329911390940347, 3.105753779411316, 2.2600672960281374, 2.3476766467094423, 2.2526920954386394, 2.2544726490974427]
